# %%
from skimage import data
from matplotlib import pyplot as plt

coins = data.coins()

print(type(coins))

plt.imshow(coins, cmap='gray')

plt.colorbar()
# Out:
# <class 'numpy.ndarray'>

# %%
cat = data.chelsea()
print(cat.shape, "  ", cat.min(), cat.max())


plt.imshow(cat)
# Out:
# (300, 451, 3)    0 231

# %%
cat[10:110, 10:110, :] = [0, 255, 0]
plt.imshow(cat)

# %%
img0 = data.chelsea()
img1 = data.rocket()
